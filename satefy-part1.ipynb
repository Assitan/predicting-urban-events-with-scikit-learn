# %%
# !pip install pandas
# !pip install pyarrow
# !pip install pandas_profiling

# %%
import numpy as np
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
from pandas_profiling import ProfileReport

# %%
nyc = pq.read_table('safety-Nyc-1.parquet')
sanFrancisco = pq.read_table('safety-SanFrancisco-1.parquet')
seattle = pq.read_table('safety-Seattle-1.parquet')

nyc = pq.read_pandas('safety-Nyc-1.parquet').to_pandas()
SanFrancisco = pq.read_pandas('safety-SanFrancisco-1.parquet').to_pandas()
Seattle = pq.read_pandas('safety-Seattle-1.parquet').to_pandas()

df = pd.DataFrame(SanFrancisco)

# nyc

# %% [markdown]
# ### Check the 5 first lines

# %%
SanFrancisco.head()
# Out:
#    requestId dataType dataSubtype             dateTime  \
# 0          1   Safety    911_Fire  2018-10-02 11:54:01
# 1          2   Safety     311_All  2018-07-08 15:00:27
# 2          3   Safety     311_All  2016-06-28 13:12:28
# 3          7   Safety     311_All  2017-03-03 09:34:49
# 4         10   Safety    911_Fire  2016-10-25 18:33:20
#
#                          category  \
# 0    Potentially Life-Threatening
# 1    Street and Sidewalk Cleaning
# 2  General Request - COUNTY CLERK
# 3          Temporary Sign Request
# 4    Potentially Life-Threatening
#
#                                    subcategory  status  \
# 0                             Medical Incident    None
# 1                                  Bulky Items  Closed
# 2                            customer_callback  Closed
# 3  Temporary Sign Request for Other_Event_Type  Closed
# 4                             Medical Incident    None
#
#                                          address   latitude   longitude  \
# ...

# %% [markdown]
# ### Get a date randomly to review the types of events that occurred at this date

# %%
pd.DataFrame(nyc).to_numpy()

# Filtering
df[df['dateTime']=='2016-06-28'].head()
# Out:
# Empty DataFrame
# Columns: [requestId, dataType, dataSubtype, dateTime, category, subcategory, status, address, latitude, longitude, source, extendedProperties]
# Index: []

# %% [markdown]
# ### Pick an address in the data and review its history of safety events

# %%
# Filtering
df[df['address']=='771 ELLIS ST, SAN FRANCISCO, CA, 94109'].head(10)
# Out:
#          requestId dataType dataSubtype             dateTime  \
# 12              33   Safety     311_All  2016-11-18 11:56:38
# 86021       208553   Safety     311_All  2018-03-01 16:01:00
# 428165     1039018   Safety     311_All  2018-04-05 17:25:00
# 749145      618499   Safety     311_All  2019-09-14 07:41:01
# 851517      867382   Safety     311_All  2019-06-22 16:39:00
# 878108      931814   Safety     311_All  2018-09-12 16:50:17
# 971113     1158040   Safety     311_All  2020-01-18 07:49:00
# 1003703      34858   Safety     311_All  2020-06-05 16:23:00
# 1197697     507578   Safety     311_All  2020-02-20 17:20:00
# 1640128     378880   Safety     311_All  2019-09-17 20:38:00
#
#                              category            subcategory  status  \
# 12              General Request - DPH              complaint  Closed
# 86021                Damaged Property  Damaged Parking_Meter  Closed
# 428165               Damaged Property  Damaged Parking_Meter  Closed
# ...

# %%
df[df['address']=='771 ELLIS ST, SAN FRANCISCO, CA, 94109'].head(10)
# Out:
#          requestId dataType dataSubtype             dateTime  \
# 12              33   Safety     311_All  2016-11-18 11:56:38
# 86021       208553   Safety     311_All  2018-03-01 16:01:00
# 428165     1039018   Safety     311_All  2018-04-05 17:25:00
# 749145      618499   Safety     311_All  2019-09-14 07:41:01
# 851517      867382   Safety     311_All  2019-06-22 16:39:00
# 878108      931814   Safety     311_All  2018-09-12 16:50:17
# 971113     1158040   Safety     311_All  2020-01-18 07:49:00
# 1003703      34858   Safety     311_All  2020-06-05 16:23:00
# 1197697     507578   Safety     311_All  2020-02-20 17:20:00
# 1640128     378880   Safety     311_All  2019-09-17 20:38:00
#
#                              category            subcategory  status  \
# 12              General Request - DPH              complaint  Closed
# 86021                Damaged Property  Damaged Parking_Meter  Closed
# 428165               Damaged Property  Damaged Parking_Meter  Closed
# ...

# %%
print("The Status column is missing", sum(SanFrancisco['status'].isna()), "values out of",len(SanFrancisco['status']))
print("The Source column is missing", sum(SanFrancisco['source'].isna()), "values out of",len(SanFrancisco['source']))
# Out:
# The Status column is missing 1405089 values out of 3958889
# The Source column is missing 1405089 values out of 3958889

# %% [markdown]
# ### Function to clean data

# %%
def clean_data(dataset):
    # convert to datetime
    df['dateTime'] = pd.to_datetime(df['dateTime'])
    # remove duplicates
    dataset = pd.DataFrame.drop_duplicates(dataset)
    # set category type
    df['source'] = df['source'].astype('category')
    df['status'] = df['status'].astype('category')
    df['dataType'] = df['dataType'].astype('category')
    df['category'] = df['category'].astype('category')
    df['subcategory'] = df['subcategory'].astype('category')

    # remove columns with missing values
    dataset = dataset.drop('status', axis=1)
    dataset = dataset.drop('source', axis=1)
    return dataset

# %% [markdown]
# ### Call the function

# %%
clean_data(SanFrancisco)
clean_data(Seattle)
clean_data(nyc)
# Out:
#          requestId dataType dataSubtype            dateTime  \
# 0                1   Safety    911_Fire 2018-10-02 11:54:01
# 1                2   Safety     311_All 2018-07-08 15:00:27
# 2                3   Safety     311_All 2016-06-28 13:12:28
# 3                7   Safety     311_All 2017-03-03 09:34:49
# 4               10   Safety    911_Fire 2016-10-25 18:33:20
# ...            ...      ...         ...                 ...
# 3958884    1203165   Safety     311_All 2016-12-13 07:11:27
# 3958885    1203168   Safety     311_All 2017-08-20 09:53:26
# 3958886    1203170   Safety     311_All 2018-06-06 10:51:00
# 3958887    1203173   Safety     311_All 2019-03-19 14:14:18
# 3958888    1203175   Safety     311_All 2018-05-29 19:58:49
#
#                                category  \
# 0          Potentially Life-Threatening
# 1          Street and Sidewalk Cleaning
# 2        General Request - COUNTY CLERK
# 3                Temporary Sign Request
# ...

# %% [markdown]
# ### Get DataTypes

# %%
df.dtypes
# Out:
# requestId                      int64
# dataType                    category
# dataSubtype                   object
# dateTime              datetime64[ns]
# category                    category
# subcategory                 category
# status                      category
# address                       object
# latitude                     float64
# longitude                    float64
# source                      category
# extendedProperties            object
# dtype: object

# %% [markdown]
# ### Get the empty data

# %%
SanFrancisco.isna().sum()
# Out:
# requestId                   0
# dataType                    0
# dataSubtype                 0
# dateTime                    0
# category                 4933
# subcategory                 0
# status                1405089
# address                     3
# latitude                    0
# longitude                   0
# source                1405089
# extendedProperties          0
# dtype: int64

# %% [markdown]
# ### Get new data

# %%
SanFrancisco.head()
# Out:
#    requestId dataType dataSubtype             dateTime  \
# 0          1   Safety    911_Fire  2018-10-02 11:54:01
# 1          2   Safety     311_All  2018-07-08 15:00:27
# 2          3   Safety     311_All  2016-06-28 13:12:28
# 3          7   Safety     311_All  2017-03-03 09:34:49
# 4         10   Safety    911_Fire  2016-10-25 18:33:20
#
#                          category  \
# 0    Potentially Life-Threatening
# 1    Street and Sidewalk Cleaning
# 2  General Request - COUNTY CLERK
# 3          Temporary Sign Request
# 4    Potentially Life-Threatening
#
#                                    subcategory  status  \
# 0                             Medical Incident    None
# 1                                  Bulky Items  Closed
# 2                            customer_callback  Closed
# 3  Temporary Sign Request for Other_Event_Type  Closed
# 4                             Medical Incident    None
#
#                                          address   latitude   longitude  \
# ...

# %% [markdown]
# ### Get a report

# %%
profile = ProfileReport(df, title='Pandas Profiling Report', explorative=True)
profile.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/25 [00:00<?, ?it/s]
# /home/assitan/.local/lib/python3.8/site-packages/scipy/stats/stats.py:4594: RuntimeWarning: overflow encountered in long_scalars
#   (2 * xtie * ytie) / m + x0 * y0 / (9 * m * (size - 2)))
# /home/assitan/.local/lib/python3.8/site-packages/pandas_profiling/model/correlations.py:133: UserWarning: There was an attempt to calculate the cramers correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"cramers": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/pandas-profiling/pandas-profiling/issues
# (include the error message: 'No axis named 1 for object type Series')
#   warnings.warn(
# ...
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ...

# %%
profile.to_notebook_iframe()
